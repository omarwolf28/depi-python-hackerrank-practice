# %% [markdown]
# # HackerRank — Python Practice
#
# Solutions to a set of exercises from HackerRank's **Python** track, solved while working through
# the basics of the language and the NumPy library. Each problem below is organized by topic and
# includes a short description followed by the solution.
#
# **Topics covered**
#
# - Python Basics (I/O, control flow, loops, functions)
# - Data Structures & Comprehensions
# - Closures & Decorators
# - NumPy
# - Math

# %% [markdown]
# ---
# ## Python Basics

# %% [markdown]
# ### 1. Say Hello, World!
#
# Print the classic `Hello, World!` greeting.

# %%
if __name__ == '__main__':
    print("Hello, World!")

# %% [markdown]
# ### 2. If-Else
#
# Read an integer and apply the Weird/Not Weird rules using `if`/`elif`.

# %%
if __name__ == '__main__':
    n = int(input().strip())
    if n%2==1 :
        print('Weird')
    elif n%2==0 and n>=2 and n<=5 :
        print('Not Weird')
    elif n%2==0 and n>=6 and n<=20 :
        print('Weird') 
    elif n%2==0 and n>20:
        print('Not Weird')

# %% [markdown]
# ### 3. Arithmetic Operators
#
# Read two integers and print their sum, difference, and product.

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a+b)
    print(a-b)
    print(a*b)

# %% [markdown]
# ### 4. Division
#
# Read two integers and print both the integer division and the float division.

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a//b)
    print(a/b)

# %% [markdown]
# ### 5. Loops
#
# Print the square of every integer from `0` to `n - 1`.

# %%
if __name__ == '__main__':
    n = int(input())
    for i in range(n):
        print(i**2)

# %% [markdown]
# ### 6. Write a Function (Leap Year)
#
# Implement `is_leap(year)`, which returns whether a given year is a leap year.

# %%
def is_leap(year):
    leap = False
    if (year%4==0 and year%100!=0)or(year%400==0):
        leap=True    
    
    return leap

year = int(input())
print(is_leap(year))

# %% [markdown]
# ### 7. Print Function
#
# Print the integers from `1` to `n` concatenated together with no separator.

# %%
if __name__ == '__main__':
    n = int(input())
    for i in range(1,n+1):
        print(i,end='')

# %% [markdown]
# ---
# ## Data Structures & Comprehensions

# %% [markdown]
# ### 8. Find the Runner-Up Score
#
# Given a list of scores, find the second-highest (runner-up) score.

# %%
if __name__ == '__main__':
    n = int(input())
    arr = map(int, input().split())
    arr=set(arr)
    arr=list(arr)
    arr.remove(max(arr))
    print(max(arr))

# %% [markdown]
# ### 9. List Comprehensions
#
# Generate every `[i, j, k]` combination in the given ranges whose sum is not equal to `n`.

# %%
if __name__ == '__main__':
    x = int(input())
    y = int(input())
    z = int(input())
    n = int(input())
    mylist=[[i,j,k] for i in range(x+1) for j in range(y+1) for k in range(z+1) if (i+j+k)!=n ]
    print(mylist)

# %% [markdown]
# ### 10. Nested Lists
#
# Given a list of students and their grades, print the name(s) of the student(s) with the second-lowest grade.

# %%
if __name__ == '__main__':
    students=[]
    for _ in range(int(input())):
        name = input()
        score = float(input())
        students.append([name,score])
        
    scores = sorted(set(i for _, i in students))
    sec_low = scores[1]
    winners = sorted(n for n, s in students if s == sec_low)
    for name in winners:
        print(name)

# %% [markdown]
# ### 11. Finding the Percentage
#
# Look up a student's scores by name and print their average, rounded to 2 decimal places.

# %%
if __name__ == '__main__':
    n = int(input())
    student_marks = {}
    for _ in range(n):
        name, *line = input().split()
        scores = list(map(float, line))
        student_marks[name] = scores
    query_name = input()
    print(student_marks[query_name])
    x=student_marks[query_name]
    sum=0
    for i in x:
        sum=sum+i
    mean=sum/len(x)
    print(f"{mean:.2f}")

# %% [markdown]
# ### 12. Lists
#
# Simulate a sequence of `insert` / `print` / `remove` / `append` / `sort` / `pop` / `reverse` commands on a list.

# %%
if __name__ == '__main__':
    n = int(input())
    numbers = []

    for _ in range(n):
        command = input().split()

        if command[0] == "insert":
            numbers.insert(int(command[1]), int(command[2]))

        elif command[0] == "print":
            print(numbers)

        elif command[0] == "remove":
            numbers.remove(int(command[1]))

        elif command[0] == "append":
            numbers.append(int(command[1]))

        elif command[0] == "sort":
            numbers.sort()

        elif command[0] == "pop":
            numbers.pop()

        elif command[0] == "reverse":
            numbers.reverse()

# %% [markdown]
# ---
# ## Closures & Decorators

# %% [markdown]
# ### 13. Standardize Mobile Number Using Decorators
#
# Use a decorator to reformat a list of phone numbers before printing them in sorted order.

# %%
def wrapper(func):
    def fun(numbers):
        formatted_numbers = []

        for number in numbers:
            number = number[-10:]
            formatted_numbers.append(
                "+91 " + number[:5] + " " + number[5:]
            )

        func(formatted_numbers)

    return fun

@wrapper
def sort_phone(l):
    print(*sorted(l), sep='\n')

if __name__ == '__main__':
    l = [input() for _ in range(int(input()))]
    sort_phone(l)

# %% [markdown]
# ### 14. Decorators 2 - Name Directory
#
# Use a decorator to sort a list of people by age and format each name with the correct title (Mr./Ms.).

# %%
import operator

def person_lister(f):
    def inner(people):
        people.sort(key=lambda person: int(person[2]))
        return [f(person) for person in people]

    return inner

@person_lister
def name_format(person):
    return ("Mr. " if person[3] == "M" else "Ms. ") + person[0] + " " + person[1]

if __name__ == '__main__':
    people = [input().split() for i in range(int(input()))]
    print(*name_format(people), sep='\n')

# %% [markdown]
# ---
# ## NumPy

# %% [markdown]
# ### 15. Array Mathematics
#
# Perform element-wise `+ - * // % **` on two 2D NumPy arrays.

# %%
import numpy as np

n, m = map(int, input().split())

a = np.array([input().split() for _ in range(n)], dtype=int)
b = np.array([input().split() for _ in range(n)], dtype=int)

print(a + b)
print(a - b)
print(a * b)
print(a // b)
print(a % b)
print(a ** b)

# %% [markdown]
# ### 16. Floor, Ceil and Rint
#
# Apply `floor`, `ceil`, and `rint` element-wise to a 1D NumPy array.

# %%
import numpy as np

np.set_printoptions(sign=' ')

a = np.array(input().split(), dtype=float)

print(np.floor(a))
print(np.ceil(a))
print(np.rint(a))

# %% [markdown]
# ### 17. Sum and Prod
#
# Sum a 2D array along an axis, then take the product of the resulting values.

# %%
import numpy as np

n, m = map(int, input().split())

a = np.array([input().split() for _ in range(n)], dtype=int)

column_sums = np.sum(a, axis=0)
print(np.prod(column_sums))

# %% [markdown]
# ### 18. Min and Max
#
# Take the row-wise minimum of a 2D array, then report the max of those minimums.

# %%
import numpy as np

n, m = map(int, input().split())

a = np.array([input().split() for _ in range(n)], dtype=int)

row_minimums = np.min(a, axis=1)
print(np.max(row_minimums))

# %% [markdown]
# ### 19. Mean, Var, and Std
#
# Compute the mean, variance, and standard deviation of a 2D array.

# %%
import numpy as np

n, m = map(int, input().split())
a = np.array([input().split() for _ in range(n)], dtype=int)

print(np.mean(a, axis=1))
print(np.var(a, axis=0))
print(round(np.std(a), 11))

# %% [markdown]
# ### 20. Dot and Cross
#
# Compute the matrix product (`dot`) of two square arrays.

# %%
import numpy as np

n = int(input())

a = np.array([input().split() for _ in range(n)], dtype=int)
b = np.array([input().split() for _ in range(n)], dtype=int)

print(np.dot(a, b))

# %% [markdown]
# ### 21. Inner and Outer
#
# Compute the inner and outer products of two 1D arrays.

# %%
import numpy as np

a = np.array(input().split(), dtype=int)
b = np.array(input().split(), dtype=int)

print(np.inner(a, b))
print(np.outer(a, b))

# %% [markdown]
# ### 22. Polynomials
#
# Evaluate a polynomial with given coefficients at a point `x` using `np.polyval`.

# %%
import numpy as np

coefficients = list(map(float, input().split()))
x = float(input())

print(np.polyval(coefficients, x))

# %% [markdown]
# ### 23. Linear Algebra
#
# Compute the determinant of a square matrix using `np.linalg.det`.

# %%
import numpy as np

n = int(input())

a = np.array([input().split() for _ in range(n)], dtype=float)

determinant = np.linalg.det(a)

print(round(determinant, 2))

# %% [markdown]
# ---
# ## Math

# %% [markdown]
# ### 24. Angle Between Two Sides of a Right Triangle
#
# Given the two legs of a right triangle, compute the angle at vertex B in degrees.

# %%
import math

ab = int(input())
bc = int(input())

angle = math.degrees(math.atan2(ab, bc))
answer = math.floor(angle + 0.5)

print(str(answer) + chr(176))

# %% [markdown]
# ### 25. Triangle Quest
#
# Print a palindromic number triangle of size `n` using exactly one `for` loop and one `print` statement.

# %%
for i in range(1, int(input()) + 1):
    print((10**i // 9)**2)
